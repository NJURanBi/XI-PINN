# %%
run main
# Out:
# device =  cuda:0
# Total number of paramerters in networks is 386
#
# ===== Time: 0.020s =====
# Step 9:
#  training loss: 3.6725e-04
# Step 19:
#  training loss: 3.3063e-04
# Step 29:
#  training loss: 7.4002e-09
# Step 39:
#  training loss: 4.2333e-14
# Step 40:
#  training loss: 9.1470e-15
# finished
# detJ: tensor(0.9978, device='cuda:0')
#
# ===== Time: 0.040s =====
# Step 9:
#  training loss: 5.2691e-07
# Step 19:
#  training loss: 4.3222e-07
# Step 29:
#  training loss: 5.2138e-08
# Step 39:
#  training loss: 1.4244e-12
# Step 49:
#  training loss: 3.1508e-13
# Step 56:
#  training loss: 6.3786e-15
# finished
# detJ: tensor(0.9958, device='cuda:0')
#
# ===== Time: 0.060s =====
# Step 9:
#  training loss: 1.7843e-09
# Step 19:
#  training loss: 1.3448e-09
# Step 29:
#  training loss: 1.3321e-10
# Step 39:
#  training loss: 9.2993e-11
# Step 49:
#  training loss: 9.2993e-11
# Step 59:
#  training loss: 9.2993e-11
# Step 69:
#  training loss: 9.2993e-11
# Step 79:
# ...
